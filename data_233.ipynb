# %%
import pandas as pd
df = pd.read_csv('stateRemain.csv')

# %%
df
# Out:
#      Unnamed: 0   BDFDB   BDPRP     BFFDB    BFPRP    CLPRB   CLPRK  CLPRP  \
# 0             0  3464.0   638.0  282138.0  49516.0      0.0   0.000    0.0
# 1             1  6295.0  1159.0  290063.0  50924.0      0.0   0.000    0.0
# 2             2  5916.0  1089.0  289782.0  50812.0      0.0   0.000    0.0
# 3             3  3159.0   581.0  288633.0  50698.0      0.0   0.000    0.0
# 4             4   126.0    23.0  266404.0  46669.0      0.0   0.000    0.0
# ..          ...     ...     ...       ...      ...      ...     ...    ...
# 245         245  4466.0   822.0    4466.0    822.0  14440.0  22.072  654.0
# 246         246  4644.0   855.0    4644.0    855.0  12590.0  22.428  561.0
# 247         247  4496.0   828.0    4496.0    828.0  15121.0  21.108  716.0
# 248         248  4115.0   757.0    4115.0    757.0   5153.0  22.665  227.0
# 249         249  3486.0   642.0    3486.0    642.0  17422.0  22.330  780.0
#
# ...

# %%
tmp_df = pd.DataFrame()
df.iloc[0, :].to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'BDFDB': 3464.0,
#  'BDPRP': 638.0,
#  'BFFDB': 282138.0,
#  'BFPRP': 49516.0,
#  'CLPRB': 0.0,
#  'CLPRK': 0.0,
#  'CLPRP': 0.0,
#  'COPRK': 5.722,
#  'EMFDB': 278674.0,
#  'ENPRP': 48878.0,
#  'GETCB': 1212.0,
#  'HYTCB': 7906.0,
#  'NCPRB': 44275.0,
#  'NGMPB': 557.0,
#  'NGMPK': 1.059,
#  'NGMPP': 526.0,
#  'NUETB': 97798.0,
#  'PAPRB': 12560.0,
#  'PAPRP': 2195.0,
#  'REPRB': 330919.0,
#  'SOTCB': 90.0,
#  'TEPRB': 441834.0,
#  'TETCB': 870370.0,
#  'WDEXB': 0.0,
#  'WDPRB': 2843.0,
#  'WDTCB': 2843.0,
#  'WSTCB': 1663.0,
#  'WWPRB': 4506.0,
#  'WYTCB': 35067.0,
#  'CO2': 48.35090988,
#  'State': 'Nebraska'}

# %%
all_df = []
tmp_df = pd.DataFrame(df.iloc[0, :]).transpose()
start = df.iloc[0, :].State

for i in range(1, len(df)):
    try:

        while (df.iloc[i, :].State == start):
            tmp_dict = df.iloc[i, :].transpose().to_dict()
            tmp_df.append(tmp_dict, ignore_index=True)
            i += 1
        all_df.append(tmp_df)
        tmp_df = pd.DataFrame(df.iloc[i, :]).transpose()
        start = df.iloc[i, :].State

    except:
        print(i)
    

all_df
# Out:
# 250
# 250
# 250
# 250
# [  Unnamed: 0   BDFDB  BDPRP     BFFDB    BFPRP CLPRB CLPRK CLPRP  COPRK  \
#  0          0  3464.0  638.0  282138.0  49516.0   0.0   0.0   0.0  5.722
#
#        EMFDB  ...     TEPRB     TETCB WDEXB   WDPRB   WDTCB   WSTCB   WWPRB  \
#  0  278674.0  ...  441834.0  870370.0   0.0  2843.0  2843.0  1663.0  4506.0
#
#       WYTCB       CO2     State
#  0  35067.0  48.35091  Nebraska
#
#  [1 rows x 32 columns],
#    Unnamed: 0   BDFDB   BDPRP     BFFDB    BFPRP CLPRB CLPRK CLPRP COPRK  \
#  5          5  9572.0  1762.0  168756.0  29682.0   0.0   0.0   0.0   0.0
#
#        EMFDB  ...     TEPRB      TETCB WDEXB    WDPRB    WDTCB    WSTCB  \
#  5  159184.0  ...  496273.0  1838918.0   0.0  63244.0  63244.0  14720.0
#
#       WWPRB    WYTCB        CO2      State
#  5  77964.0  91706.0  91.100543  Minnesota
#
#  [1 rows x 32 columns],
#    Unnamed: 0   BDFDB   BDPRP     BFFDB    BFPRP CLPRB CLPRK CLPRP  COPRK  \
# ...

# %%
grouped = df.groupby(df.State)
df_new = grouped.get_group("Alaska")
df_new
state_lst = set([df.loc[i, 'State'] for i in range(len(df))])

all_df = []
for state in state_lst: #state list
    all_df.append(grouped.get_group(state))
all_df[0]
# Out:
#      Unnamed: 0   BDFDB   BDPRP    BFFDB   BFPRP      CLPRB   CLPRK    CLPRP  \
# 190         190  4761.0   876.0  18865.0  3350.0  1168609.0  25.468  45885.0
# 191         191  5515.0  1015.0  18741.0  3335.0  1260516.0  25.656  49131.0
# 192         192  8265.0  1521.0  20894.0  3733.0  1278056.0  25.577  49968.0
# 193         193  5557.0  1023.0  20133.0  3582.0  1250902.0  24.979  50078.0
# 194         194  3216.0   592.0  16251.0  2875.0  1278078.0  25.124  50872.0
#
#      COPRK    EMFDB  ...      TEPRB      TETCB  WDEXB    WDPRB    WDTCB  \
# 190  5.722  14104.0  ...  7794315.0  3762485.0    0.0  76880.0  76880.0
# 191  5.723  13227.0  ...  8143154.0  3766880.0    0.0  76403.0  76403.0
# 192  5.706  12628.0  ...  9040917.0  3933425.0    0.0  81527.0  81527.0
# 193  5.698  14576.0  ...  9655336.0  3818814.0    0.0  78020.0  78020.0
# 194  5.717  13035.0  ...  7480950.0  3897610.0    0.0  81888.0  81888.0
#
#        WSTCB     WWPRB    WYTCB         CO2         State
# ...

# %%
state_lst = set([df.loc[i, 'State'] for i in range(len(df))])

# %%
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming'}
